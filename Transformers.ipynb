# %% [markdown]
# <a href="https://colab.research.google.com/github/JyotiMehtre/Google-colab-notebook/blob/main/Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
result = classifier(" I Love the product, it works wonderful")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
result
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998863935470581}]

# %%
classifier = pipeline("sentiment-analysis", model="gpt2")
result = classifier(" I Love the product, it works wonderful")
result
# Out:
# Some weights of GPT2ForSequenceClassification were not initialized from the model checkpoint at gpt2 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cuda:0
# [{'label': 'LABEL_1', 'score': 0.9924018383026123}]

# %%
from transformers import pipeline

pipe = pipeline("text-classification", model="tabularisai/multilingual-sentiment-analysis")

sentence = "I Love this product!It's amazing and works perfectly."
result = pipe(sentence)

print(result)
# Out:
# config.json:   0%|          | 0.00/851 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Device set to use cuda:0
# [{'label': 'Very Positive', 'score': 0.5558347702026367}]

# %%
# !git clone https://github.com/JyotiMehtre/Google-colab-notebook.git
# %cd Google-colab-notebook

# !git config --global user.email "jyotimehtre90@gmail.com"
# !git config --global user.name "Jyoti Mehtre"

# !cp /content/transformers.ipynb /content/Google-colab-notebook/
# !git add transformers.ipynb
# !git commit -m "Initial notebook commit"
# !git push origin main
# Out:
# Cloning into 'Google-colab-notebook'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/Google-colab-notebook/Google-colab-notebook
# cp: cannot stat '/content/transformers.ipynb': No such file or directory
# fatal: pathspec 'transformers.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
